# %%
#importing dependencies
import pandas as pd
import gmaps
import requests
import numpy as np
from citipy import citipy
from datetime import datetime
import time

#importing the api keys
from config import weather_api_key

# %%
#sets the base URL to for the weather map API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#creates a set of random ;latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)

#zips both functions having the same index in their respective array into a tuple
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#adds the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#creates a list for holding the cities
cities = []

#identify the nearest city for each coordinates
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if city is unique then will be added to the cities list
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 755

# %%
#creates an empty list to hold the weather data
city_data =[]

#print the beginning of the logging
print('Beginning Data Retrieval     ')
print('-----------------------------')

#creates counters
record_count = 1
set_count = 1

#loops through all the cities in our list
for i, city in enumerate(cities):
    time.sleep(1)
        
    #groups cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
        
    #creates the endpoint URL with each city
    city_url = url + '&q=' + city.replace(' ', '+')
    
    #logs the URl, records and set numbers and the city
    print(f'Processing Record {record_count} of set {set_count} | {city}')
    
    #adds 1 to the record count
    record_count += 1
        #Run an API request for each of the cities
    try:
        #parses the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        
        #parses the data that we need
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        #converts the date into ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        #appends the city information into the city_data list
        city_data.append({'City': city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Current Description': city_description})
    
    #if an error is experienced. skip the city
    except: #Exception as e:
        print('City not found. Skipping...')
        #print(e)
        pass
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | saint-philippe
# Processing Record 2 of set 1 | yellowknife
# Processing Record 3 of set 1 | geraldton
# Processing Record 4 of set 1 | carnarvon
# Processing Record 5 of set 1 | clyde river
# Processing Record 6 of set 1 | alofi
# Processing Record 7 of set 1 | fortuna
# Processing Record 8 of set 1 | chuy
# Processing Record 9 of set 1 | busselton
# Processing Record 10 of set 1 | castro
# Processing Record 11 of set 1 | jamestown
# Processing Record 12 of set 1 | qingdao
# Processing Record 13 of set 1 | kuloy
# Processing Record 14 of set 1 | sterling
# Processing Record 15 of set 1 | alice springs
# Processing Record 16 of set 1 | ushuaia
# Processing Record 17 of set 1 | hilo
# Processing Record 18 of set 1 | tuktoyaktuk
# Processing Record 19 of set 1 | avarua
# Processing Record 20 of set 1 | kaitangata
# Processing Record 21 of set 1 | barbar
# City not found. Skipping...
# Processing Record 22 of set 1 | atar
# Processing Record 23 of set 1 | torbay
# Processing Record 24 of set 1 | rikitea
# Processing Record 25 of set 1 | sibolga
# Processing Record 26 of set 1 | severo-kurilsk
# Processing Record 27 of set 1 | cockburn town
# Processing Record 28 of set 1 | hay river
# Processing Record 29 of set 1 | lucea
# Processing Record 30 of set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of set 1 | klaksvik
# Processing Record 32 of set 1 | tsihombe
# City not found. Skipping...
# Processing Record 33 of set 1 | namibe
# Processing Record 34 of set 1 | dhidhdhoo
# Processing Record 35 of set 1 | puerto maldonado
# Processing Record 36 of set 1 | new norfolk
# Processing Record 37 of set 1 | los llanos de aridane
# Processing Record 38 of set 1 | shingu
# Processing Record 39 of set 1 | upernavik
# Processing Record 40 of set 1 | omboue
# Processing Record 41 of set 1 | pingliang
# Processing Record 42 of set 1 | banda aceh
# Processing Record 43 of set 1 | laguna
# Processing Record 44 of set 1 | yeppoon
# Processing Record 45 of set 1 | mahebourg
# Processing Record 46 of set 1 | vaini
# Processing Record 47 of set 1 | butaritari
# Processing Record 48 of set 1 | mataura
# Processing Record 49 of set 1 | brae
# Processing Record 50 of set 1 | yabassi
# Processing Record 1 of set 2 | amderma
# City not found. Skipping...
# Processing Record 2 of set 2 | victoria
# Processing Record 3 of set 2 | weligama
# Processing Record 4 of set 2 | touros
# Processing Record 5 of set 2 | puerto ayora
# Processing Record 6 of set 2 | mikhaylovka
# Processing Record 7 of set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of set 2 | barrow
# Processing Record 9 of set 2 | port blair
# Processing Record 10 of set 2 | ilmajoki
# Processing Record 11 of set 2 | klyuchi
# Processing Record 12 of set 2 | sinnamary
# Processing Record 13 of set 2 | ponta do sol
# Processing Record 14 of set 2 | barawe
# City not found. Skipping...
# Processing Record 15 of set 2 | cidreira
# Processing Record 16 of set 2 | aykhal
# Processing Record 17 of set 2 | yerofey pavlovich
# Processing Record 18 of set 2 | dikson
# Processing Record 19 of set 2 | codrington
# Processing Record 20 of set 2 | east london
# Processing Record 21 of set 2 | berbera
# Processing Record 22 of set 2 | punta arenas
# Processing Record 23 of set 2 | dwarka
# Processing Record 24 of set 2 | narsaq
# Processing Record 25 of set 2 | port alfred
# Processing Record 26 of set 2 | hobart
# Processing Record 27 of set 2 | beipiao
# Processing Record 28 of set 2 | hithadhoo
# Processing Record 29 of set 2 | thompson
# Processing Record 30 of set 2 | san patricio
# Processing Record 31 of set 2 | khatanga
# Processing Record 32 of set 2 | chokurdakh
# Processing Record 33 of set 2 | ugoofaaru
# Processing Record 34 of set 2 | mar del plata
# Processing Record 35 of set 2 | kinshasa
# Processing Record 36 of set 2 | kahului
# Processing Record 37 of set 2 | filingue
# Processing Record 38 of set 2 | naze
# Processing Record 39 of set 2 | osoyoos
# Processing Record 40 of set 2 | chipinge
# Processing Record 41 of set 2 | steamboat springs
# Processing Record 42 of set 2 | bairiki
# Processing Record 43 of set 2 | tuatapere
# Processing Record 44 of set 2 | ossora
# Processing Record 45 of set 2 | cape town
# Processing Record 46 of set 2 | bambous virieux
# Processing Record 47 of set 2 | esperance
# Processing Record 48 of set 2 | nikolayevka
# Processing Record 49 of set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of set 2 | mayumba
# Processing Record 1 of set 3 | atuona
# Processing Record 2 of set 3 | itoman
# Processing Record 3 of set 3 | lebu
# Processing Record 4 of set 3 | ketchikan
# Processing Record 5 of set 3 | gediz
# Processing Record 6 of set 3 | port macquarie
# Processing Record 7 of set 3 | vaitupu
# City not found. Skipping...
# Processing Record 8 of set 3 | mtsensk
# Processing Record 9 of set 3 | bolshoye ignatovo
# City not found. Skipping...
# Processing Record 10 of set 3 | norman wells
# Processing Record 11 of set 3 | dinguiraye
# Processing Record 12 of set 3 | ribeira grande
# Processing Record 13 of set 3 | gobabis
# Processing Record 14 of set 3 | kasongo-lunda
# Processing Record 15 of set 3 | goure
# Processing Record 16 of set 3 | sao sebastiao
# Processing Record 17 of set 3 | aswan
# Processing Record 18 of set 3 | barentsburg
# City not found. Skipping...
# Processing Record 19 of set 3 | evensk
# Processing Record 20 of set 3 | vardo
# Processing Record 21 of set 3 | anchorage
# Processing Record 22 of set 3 | salalah
# Processing Record 23 of set 3 | malakal
# Processing Record 24 of set 3 | aklavik
# Processing Record 25 of set 3 | cherskiy
# Processing Record 26 of set 3 | ostrovnoy
# Processing Record 27 of set 3 | kapaa
# Processing Record 28 of set 3 | ulladulla
# Processing Record 29 of set 3 | kuche
# City not found. Skipping...
# Processing Record 30 of set 3 | bubaque
# Processing Record 31 of set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of set 3 | ambulu
# Processing Record 33 of set 3 | hwange
# Processing Record 34 of set 3 | longyearbyen
# Processing Record 35 of set 3 | souillac
# Processing Record 36 of set 3 | saskylakh
# Processing Record 37 of set 3 | husavik
# Processing Record 38 of set 3 | krasnoarmeysk
# Processing Record 39 of set 3 | yulara
# Processing Record 40 of set 3 | nemuro
# Processing Record 41 of set 3 | coahuayana
# Processing Record 42 of set 3 | albany
# Processing Record 43 of set 3 | fare
# Processing Record 44 of set 3 | chiredzi
# Processing Record 45 of set 3 | qaanaaq
# Processing Record 46 of set 3 | san andres
# Processing Record 47 of set 3 | brigantine
# Processing Record 48 of set 3 | balkanabat
# Processing Record 49 of set 3 | arraial do cabo
# Processing Record 50 of set 3 | tammisaari
# Processing Record 1 of set 4 | kimbe
# Processing Record 2 of set 4 | beloha
# Processing Record 3 of set 4 | cabo san lucas
# Processing Record 4 of set 4 | broome
# Processing Record 5 of set 4 | polovinnoye
# Processing Record 6 of set 4 | labutta
# City not found. Skipping...
# Processing Record 7 of set 4 | olinda
# Processing Record 8 of set 4 | tasiilaq
# Processing Record 9 of set 4 | anito
# Processing Record 10 of set 4 | oussouye
# Processing Record 11 of set 4 | porto velho
# Processing Record 12 of set 4 | wuwei
# Processing Record 13 of set 4 | bethel
# Processing Record 14 of set 4 | praia da vitoria
# Processing Record 15 of set 4 | port alberni
# Processing Record 16 of set 4 | mareeba
# Processing Record 17 of set 4 | byron bay
# Processing Record 18 of set 4 | amatenango del valle
# Processing Record 19 of set 4 | hermanus
# Processing Record 20 of set 4 | tonstad
# Processing Record 21 of set 4 | adrar
# Processing Record 22 of set 4 | parfenyevo
# Processing Record 23 of set 4 | kuragino
# Processing Record 24 of set 4 | russkaya polyana
# Processing Record 25 of set 4 | port elizabeth
# Processing Record 26 of set 4 | cartagena
# Processing Record 27 of set 4 | canitas
# City not found. Skipping...
# Processing Record 28 of set 4 | buala
# Processing Record 29 of set 4 | bambanglipuro
# Processing Record 30 of set 4 | ilulissat
# Processing Record 31 of set 4 | tutoia
# Processing Record 32 of set 4 | hasaki
# Processing Record 33 of set 4 | satitoa
# City not found. Skipping...
# Processing Record 34 of set 4 | san cataldo
# Processing Record 35 of set 4 | sao jose da coroa grande
# Processing Record 36 of set 4 | sataua
# City not found. Skipping...
# Processing Record 37 of set 4 | eldikan
# City not found. Skipping...
# Processing Record 38 of set 4 | piraju
# Processing Record 39 of set 4 | lopatino
# Processing Record 40 of set 4 | skalistyy
# City not found. Skipping...
# Processing Record 41 of set 4 | faanui
# Processing Record 42 of set 4 | bacolod
# Processing Record 43 of set 4 | tigil
# Processing Record 44 of set 4 | prince rupert
# Processing Record 45 of set 4 | nikolskoye
# Processing Record 46 of set 4 | bluff
# Processing Record 47 of set 4 | bengkulu
# Processing Record 48 of set 4 | jiexiu
# Processing Record 49 of set 4 | saint-augustin
# Processing Record 50 of set 4 | kodinsk
# Processing Record 1 of set 5 | north bend
# Processing Record 2 of set 5 | rudnya
# Processing Record 3 of set 5 | baruun-urt
# Processing Record 4 of set 5 | atambua
# Processing Record 5 of set 5 | uba
# Processing Record 6 of set 5 | goderich
# Processing Record 7 of set 5 | dublin
# Processing Record 8 of set 5 | toliary
# City not found. Skipping...
# Processing Record 9 of set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of set 5 | coulihaut
# City not found. Skipping...
# Processing Record 11 of set 5 | harper
# Processing Record 12 of set 5 | mackay
# Processing Record 13 of set 5 | bocas del toro
# Processing Record 14 of set 5 | namtsy
# Processing Record 15 of set 5 | lorengau
# Processing Record 16 of set 5 | bouna
# Processing Record 17 of set 5 | esil
# Processing Record 18 of set 5 | enumclaw
# Processing Record 19 of set 5 | sinkat
# City not found. Skipping...
# Processing Record 20 of set 5 | ygatimi
# Processing Record 21 of set 5 | belushya guba
# City not found. Skipping...
# Processing Record 22 of set 5 | guerrero negro
# Processing Record 23 of set 5 | bredasdorp
# Processing Record 24 of set 5 | provideniya
# Processing Record 25 of set 5 | saint combs
# City not found. Skipping...
# Processing Record 26 of set 5 | sao paulo de olivenca
# Processing Record 27 of set 5 | marang
# Processing Record 28 of set 5 | papara
# Processing Record 29 of set 5 | havelock
# Processing Record 30 of set 5 | surt
# Processing Record 31 of set 5 | bathsheba
# Processing Record 32 of set 5 | xianshuigu
# Processing Record 33 of set 5 | pisco
# Processing Record 34 of set 5 | sao filipe
# Processing Record 35 of set 5 | collie
# Processing Record 36 of set 5 | gimli
# Processing Record 37 of set 5 | gunnedah
# Processing Record 38 of set 5 | shwebo
# Processing Record 39 of set 5 | khonuu
# City not found. Skipping...
# Processing Record 40 of set 5 | belmonte
# Processing Record 41 of set 5 | caravelas
# Processing Record 42 of set 5 | saldanha
# Processing Record 43 of set 5 | tura
# Processing Record 44 of set 5 | shinshiro
# Processing Record 45 of set 5 | trairi
# Processing Record 46 of set 5 | kununurra
# Processing Record 47 of set 5 | vao
# Processing Record 48 of set 5 | madaba
# Processing Record 49 of set 5 | xiongzhou
# Processing Record 50 of set 5 | bone
# Processing Record 1 of set 6 | half moon bay
# Processing Record 2 of set 6 | liverpool
# Processing Record 3 of set 6 | srednekolymsk
# Processing Record 4 of set 6 | samusu
# City not found. Skipping...
# Processing Record 5 of set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 6 of set 6 | richards bay
# Processing Record 7 of set 6 | tirano
# Processing Record 8 of set 6 | labuhan
# Processing Record 9 of set 6 | troitsko-pechorsk
# Processing Record 10 of set 6 | den helder
# Processing Record 11 of set 6 | roma
# Processing Record 12 of set 6 | itarema
# Processing Record 13 of set 6 | listvyanskiy
# Processing Record 14 of set 6 | bajil
# Processing Record 15 of set 6 | kruisfontein
# Processing Record 16 of set 6 | plerin
# Processing Record 17 of set 6 | jining
# Processing Record 18 of set 6 | kodiak
# Processing Record 19 of set 6 | homer
# Processing Record 20 of set 6 | hirara
# Processing Record 21 of set 6 | novozybkov
# Processing Record 22 of set 6 | faya
# Processing Record 23 of set 6 | kalmunai
# Processing Record 24 of set 6 | pichayevo
# Processing Record 25 of set 6 | la rioja
# Processing Record 26 of set 6 | upington
# Processing Record 27 of set 6 | padre bernardo
# Processing Record 28 of set 6 | davila
# Processing Record 29 of set 6 | biltine
# Processing Record 30 of set 6 | lupiro
# Processing Record 31 of set 6 | mackenzie
# Processing Record 32 of set 6 | yeniseysk
# Processing Record 33 of set 6 | waipawa
# Processing Record 34 of set 6 | montepuez
# Processing Record 35 of set 6 | sri aman
# Processing Record 36 of set 6 | ribeira brava
# Processing Record 37 of set 6 | san policarpo
# Processing Record 38 of set 6 | luderitz
# Processing Record 39 of set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of set 6 | katsuura
# Processing Record 41 of set 6 | temir
# Processing Record 42 of set 6 | imperial
# Processing Record 43 of set 6 | ucluelet
# Processing Record 44 of set 6 | mocuba
# Processing Record 45 of set 6 | mossendjo
# Processing Record 46 of set 6 | langarud
# Processing Record 47 of set 6 | cayenne
# Processing Record 48 of set 6 | tawkar
# City not found. Skipping...
# Processing Record 49 of set 6 | anloga
# Processing Record 50 of set 6 | talaja
# Processing Record 1 of set 7 | piopio
# Processing Record 2 of set 7 | tremedal
# Processing Record 3 of set 7 | gazojak
# Processing Record 4 of set 7 | krasnoselkup
# Processing Record 5 of set 7 | bulgan
# Processing Record 6 of set 7 | south venice
# Processing Record 7 of set 7 | gigmoto
# Processing Record 8 of set 7 | martil
# Processing Record 9 of set 7 | olgod
# Processing Record 10 of set 7 | bargal
# City not found. Skipping...
# Processing Record 11 of set 7 | saint-joseph
# Processing Record 12 of set 7 | kautokeino
# Processing Record 13 of set 7 | sitka
# Processing Record 14 of set 7 | moyale
# Processing Record 15 of set 7 | yumen
# Processing Record 16 of set 7 | zakamensk
# Processing Record 17 of set 7 | shache
# Processing Record 18 of set 7 | fairbanks
# Processing Record 19 of set 7 | sidrolandia
# Processing Record 20 of set 7 | voh
# Processing Record 21 of set 7 | lingao
# Processing Record 22 of set 7 | kavieng
# Processing Record 23 of set 7 | disraeli
# Processing Record 24 of set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of set 7 | khani
# Processing Record 26 of set 7 | sisimiut
# Processing Record 27 of set 7 | georgetown
# Processing Record 28 of set 7 | marawi
# Processing Record 29 of set 7 | talas
# Processing Record 30 of set 7 | sabancuy
# Processing Record 31 of set 7 | lata
# Processing Record 32 of set 7 | mbarara
# Processing Record 33 of set 7 | balyaga
# Processing Record 34 of set 7 | aasiaat
# Processing Record 35 of set 7 | ngawi
# Processing Record 36 of set 7 | coihaique
# Processing Record 37 of set 7 | kenai
# Processing Record 38 of set 7 | tecolutla
# Processing Record 39 of set 7 | lesnoy
# Processing Record 40 of set 7 | el rosario
# Processing Record 41 of set 7 | dunedin
# Processing Record 42 of set 7 | ust-karsk
# Processing Record 43 of set 7 | marzuq
# Processing Record 44 of set 7 | hanna
# Processing Record 45 of set 7 | pimentel
# Processing Record 46 of set 7 | marsh harbour
# Processing Record 47 of set 7 | chingirlau
# Processing Record 48 of set 7 | las palmas
# Processing Record 49 of set 7 | yar-sale
# Processing Record 50 of set 7 | avera
# Processing Record 1 of set 8 | vestbygda
# City not found. Skipping...
# Processing Record 2 of set 8 | remanso
# Processing Record 3 of set 8 | huilong
# Processing Record 4 of set 8 | mopti
# Processing Record 5 of set 8 | muros
# Processing Record 6 of set 8 | saleaula
# City not found. Skipping...
# Processing Record 7 of set 8 | sayansk
# Processing Record 8 of set 8 | sao joao da barra
# Processing Record 9 of set 8 | san cristobal
# Processing Record 10 of set 8 | wajima
# Processing Record 11 of set 8 | senno
# Processing Record 12 of set 8 | kiruna
# Processing Record 13 of set 8 | palamos
# Processing Record 14 of set 8 | hamilton
# Processing Record 15 of set 8 | vestmannaeyjar
# Processing Record 16 of set 8 | te anau
# Processing Record 17 of set 8 | premia de mar
# Processing Record 18 of set 8 | acarau
# Processing Record 19 of set 8 | kemijarvi
# Processing Record 20 of set 8 | rudbar
# Processing Record 21 of set 8 | imeni poliny osipenko
# Processing Record 22 of set 8 | nakusp
# Processing Record 23 of set 8 | constitucion
# Processing Record 24 of set 8 | kirensk
# Processing Record 25 of set 8 | inhambane
# Processing Record 26 of set 8 | okhotsk
# Processing Record 27 of set 8 | grindavik
# Processing Record 28 of set 8 | port-gentil
# Processing Record 29 of set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of set 8 | aitape
# Processing Record 31 of set 8 | airai
# Processing Record 32 of set 8 | myaundzha
# Processing Record 33 of set 8 | manzhouli
# Processing Record 34 of set 8 | arica
# Processing Record 35 of set 8 | perdoes
# Processing Record 36 of set 8 | bireun
# Processing Record 37 of set 8 | porvoo
# Processing Record 38 of set 8 | bur gabo
# City not found. Skipping...
# Processing Record 39 of set 8 | khash
# Processing Record 40 of set 8 | kananga
# Processing Record 41 of set 8 | santa cruz cabralia
# Processing Record 42 of set 8 | grand gaube
# Processing Record 43 of set 8 | komsomolskiy
# Processing Record 44 of set 8 | peleduy
# Processing Record 45 of set 8 | teya
# Processing Record 46 of set 8 | saltillo
# Processing Record 47 of set 8 | virginia beach
# Processing Record 48 of set 8 | idil
# Processing Record 49 of set 8 | bratsk
# Processing Record 50 of set 8 | nome
# Processing Record 1 of set 9 | veracruz
# Processing Record 2 of set 9 | nancha
# Processing Record 3 of set 9 | ekuvukeni
# Processing Record 4 of set 9 | chilca
# Processing Record 5 of set 9 | wanning
# Processing Record 6 of set 9 | lagoa
# Processing Record 7 of set 9 | puerto lopez
# Processing Record 8 of set 9 | yatou
# Processing Record 9 of set 9 | basco
# Processing Record 10 of set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of set 9 | korla
# Processing Record 12 of set 9 | ruidoso
# Processing Record 13 of set 9 | fukue
# Processing Record 14 of set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of set 9 | ginir
# Processing Record 16 of set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 17 of set 9 | ponta delgada
# Processing Record 18 of set 9 | abu dhabi
# Processing Record 19 of set 9 | kutum
# Processing Record 20 of set 9 | ashqelon
# Processing Record 21 of set 9 | samarai
# Processing Record 22 of set 9 | solnechnyy
# Processing Record 23 of set 9 | balao
# Processing Record 24 of set 9 | dudinka
# Processing Record 25 of set 9 | charters towers
# Processing Record 26 of set 9 | tuy hoa
# Processing Record 27 of set 9 | taltal
# Processing Record 28 of set 9 | vestmanna
# Processing Record 29 of set 9 | talnakh
# Processing Record 30 of set 9 | riyadh
# Processing Record 31 of set 9 | aquiraz
# Processing Record 32 of set 9 | eldorado
# Processing Record 33 of set 9 | ambilobe
# Processing Record 34 of set 9 | tiksi
# Processing Record 35 of set 9 | jaumave
# Processing Record 36 of set 9 | leh
# Processing Record 37 of set 9 | saint marys
# Processing Record 38 of set 9 | alekseyevsk
# Processing Record 39 of set 9 | lumeje
# Processing Record 40 of set 9 | eureka
# Processing Record 41 of set 9 | mount isa
# Processing Record 42 of set 9 | ahipara
# Processing Record 43 of set 9 | afua
# Processing Record 44 of set 9 | casper
# Processing Record 45 of set 9 | paradwip
# City not found. Skipping...
# Processing Record 46 of set 9 | panguiranan
# Processing Record 47 of set 9 | siuna
# Processing Record 48 of set 9 | sorland
# Processing Record 49 of set 9 | deputatskiy
# Processing Record 50 of set 9 | santa maria da vitoria
# Processing Record 1 of set 10 | dongsheng
# Processing Record 2 of set 10 | lasa
# Processing Record 3 of set 10 | namatanai
# Processing Record 4 of set 10 | petauke
# Processing Record 5 of set 10 | egvekinot
# Processing Record 6 of set 10 | opuwo
# Processing Record 7 of set 10 | dolores hidalgo
# Processing Record 8 of set 10 | flin flon
# Processing Record 9 of set 10 | neyshabur
# Processing Record 10 of set 10 | pandan
# Processing Record 11 of set 10 | pochutla
# Processing Record 12 of set 10 | tabou
# Processing Record 13 of set 10 | tidore
# City not found. Skipping...
# Processing Record 14 of set 10 | veraval
# Processing Record 15 of set 10 | doha
# Processing Record 16 of set 10 | niksic
# Processing Record 17 of set 10 | soyo
# Processing Record 18 of set 10 | mrakovo
# Processing Record 19 of set 10 | sivaki
# Processing Record 20 of set 10 | juneau
# Processing Record 21 of set 10 | leningradskiy
# Processing Record 22 of set 10 | huarmey
# Processing Record 23 of set 10 | ancud
# Processing Record 24 of set 10 | fort william
# Processing Record 25 of set 10 | noumea
# Processing Record 26 of set 10 | ust-kulom
# Processing Record 27 of set 10 | kamaishi
# Processing Record 28 of set 10 | poopo
# Processing Record 29 of set 10 | churapcha
# Processing Record 30 of set 10 | luau
# Processing Record 31 of set 10 | henties bay
# Processing Record 32 of set 10 | gualeguaychu
# Processing Record 33 of set 10 | sorvag
# City not found. Skipping...
# Processing Record 34 of set 10 | butajira
# Processing Record 35 of set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of set 10 | gat
# Processing Record 37 of set 10 | kaeo
# Processing Record 38 of set 10 | bandarbeyla
# Processing Record 39 of set 10 | kabinda
# Processing Record 40 of set 10 | gizo
# Processing Record 41 of set 10 | high level
# Processing Record 42 of set 10 | launceston
# Processing Record 43 of set 10 | sabha
# Processing Record 44 of set 10 | portland
# Processing Record 45 of set 10 | sabang
# Processing Record 46 of set 10 | nauen
# Processing Record 47 of set 10 | krasnovishersk
# Processing Record 48 of set 10 | ati
# Processing Record 49 of set 10 | college
# Processing Record 50 of set 10 | roald
# Processing Record 1 of set 11 | qaqortoq
# Processing Record 2 of set 11 | winsum
# Processing Record 3 of set 11 | bangassou
# Processing Record 4 of set 11 | tromso
# Processing Record 5 of set 11 | magam
# Processing Record 6 of set 11 | alyangula
# Processing Record 7 of set 11 | emba
# Processing Record 8 of set 11 | port hardy
# Processing Record 9 of set 11 | shar
# Processing Record 10 of set 11 | manosque
# Processing Record 11 of set 11 | robertsport
# Processing Record 12 of set 11 | bardiyah
# Processing Record 13 of set 11 | vila franca do campo
# Processing Record 14 of set 11 | zhigansk
# Processing Record 15 of set 11 | magadan
# Processing Record 16 of set 11 | sao jose do egito
# Processing Record 17 of set 11 | jian
# Processing Record 18 of set 11 | union
# Processing Record 19 of set 11 | ekhabi
# Processing Record 20 of set 11 | nenjiang
# Processing Record 21 of set 11 | beyneu
# Processing Record 22 of set 11 | troitskoye
# Processing Record 23 of set 11 | teguldet
# Processing Record 24 of set 11 | mitsamiouli
# Processing Record 25 of set 11 | sangar
# Processing Record 26 of set 11 | maldonado
# Processing Record 27 of set 11 | christchurch
# Processing Record 28 of set 11 | neiafu
# Processing Record 29 of set 11 | wanxian
# Processing Record 30 of set 11 | lazaro cardenas
# Processing Record 31 of set 11 | zhuhai
# Processing Record 32 of set 11 | san miguel
# Processing Record 33 of set 11 | along
# Processing Record 34 of set 11 | pontes e lacerda
# Processing Record 35 of set 11 | puerto escondido
# Processing Record 36 of set 11 | pevek
# Processing Record 37 of set 11 | aranos
# Processing Record 38 of set 11 | yenagoa
# Processing Record 39 of set 11 | nouadhibou
# Processing Record 40 of set 11 | verkhoyansk
# Processing Record 41 of set 11 | maumere
# Processing Record 42 of set 11 | padang
# Processing Record 43 of set 11 | pachino
# Processing Record 44 of set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of set 11 | kerteh
# City not found. Skipping...
# Processing Record 46 of set 11 | villamontes
# Processing Record 47 of set 11 | willowmore
# Processing Record 48 of set 11 | port moresby
# Processing Record 49 of set 11 | gornopravdinsk
# Processing Record 50 of set 11 | rungata
# City not found. Skipping...
# Processing Record 1 of set 12 | gilazi
# City not found. Skipping...
# Processing Record 2 of set 12 | tessalit
# Processing Record 3 of set 12 | ulaanbaatar
# Processing Record 4 of set 12 | camara de lobos
# Processing Record 5 of set 12 | ulaangom
# Processing Record 6 of set 12 | meulaboh
# Processing Record 7 of set 12 | bagotville
# Processing Record 8 of set 12 | ust-ilimsk
# Processing Record 9 of set 12 | baykit
# Processing Record 10 of set 12 | kapoeta
# Processing Record 11 of set 12 | warrnambool
# Processing Record 12 of set 12 | velingara
# Processing Record 13 of set 12 | batemans bay
# Processing Record 14 of set 12 | shinpokh
# Processing Record 15 of set 12 | bereda
# Processing Record 16 of set 12 | honiara
# Processing Record 17 of set 12 | karaul
# City not found. Skipping...
# Processing Record 18 of set 12 | hambantota
# Processing Record 19 of set 12 | thung song
# Processing Record 20 of set 12 | bjornevatn
# Processing Record 21 of set 12 | bahia blanca
# Processing Record 22 of set 12 | rincon
# Processing Record 23 of set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of set 12 | merke
# Processing Record 25 of set 12 | aljezur
# Processing Record 26 of set 12 | zolnoye
# City not found. Skipping...
# Processing Record 27 of set 12 | mecca
# Processing Record 28 of set 12 | vedaranniyam
# City not found. Skipping...
# Processing Record 29 of set 12 | mumford
# Processing Record 30 of set 12 | yarkovo
# Processing Record 31 of set 12 | galeana
# Processing Record 32 of set 12 | tsogni
# Processing Record 33 of set 12 | bekovo
# Processing Record 34 of set 12 | strelka
# Processing Record 35 of set 12 | banfora
# Processing Record 36 of set 12 | saint george
# Processing Record 37 of set 12 | lexington
# Processing Record 38 of set 12 | axim
# Processing Record 39 of set 12 | mayo
# Processing Record 40 of set 12 | halalo
# City not found. Skipping...
# Processing Record 41 of set 12 | charyshskoye
# Processing Record 42 of set 12 | port hueneme
# Processing Record 43 of set 12 | lima
# Processing Record 44 of set 12 | chateauroux
# Processing Record 45 of set 12 | ewo
# Processing Record 46 of set 12 | antofagasta
# Processing Record 47 of set 12 | khasan
# Processing Record 48 of set 12 | nelson bay
# Processing Record 49 of set 12 | galiwinku
# City not found. Skipping...
# Processing Record 50 of set 12 | palma
# Processing Record 1 of set 13 | kavaratti
# Processing Record 2 of set 13 | koslan
# Processing Record 3 of set 13 | comodoro rivadavia
# Processing Record 4 of set 13 | olafsvik
# Processing Record 5 of set 13 | zyryanskoye
# Processing Record 6 of set 13 | barra do corda
# Processing Record 7 of set 13 | nioro
# Processing Record 8 of set 13 | kupang
# Processing Record 9 of set 13 | jupiter
# Processing Record 10 of set 13 | coquimbo
# Processing Record 11 of set 13 | mudhol
# Processing Record 12 of set 13 | alberton
# Processing Record 13 of set 13 | rawson
# Processing Record 14 of set 13 | nishihara
# Processing Record 15 of set 13 | groningen
# Processing Record 16 of set 13 | talcahuano
# Processing Record 17 of set 13 | champerico
# Processing Record 18 of set 13 | northam
# Processing Record 19 of set 13 | longkou
# Processing Record 20 of set 13 | panlaitan
# Processing Record 21 of set 13 | tarudant
# City not found. Skipping...
# Processing Record 22 of set 13 | the pas
# Processing Record 23 of set 13 | katangli
# Processing Record 24 of set 13 | povenets
# Processing Record 25 of set 13 | kitimat
# Processing Record 26 of set 13 | moratuwa
# Processing Record 27 of set 13 | kuching
# Processing Record 28 of set 13 | xai-xai
# Processing Record 29 of set 13 | laguna de perlas
# Processing Record 30 of set 13 | aflu
# City not found. Skipping...
# Processing Record 31 of set 13 | mazatlan
# Processing Record 32 of set 13 | parkes
# Processing Record 33 of set 13 | opochka
# Processing Record 34 of set 13 | sandi
# Processing Record 35 of set 13 | changli
# Processing Record 36 of set 13 | rio grande
# Processing Record 37 of set 13 | fort nelson
# Processing Record 38 of set 13 | megion
# Processing Record 39 of set 13 | nuevo casas grandes
# Processing Record 40 of set 13 | anar darreh
# City not found. Skipping...
# Processing Record 41 of set 13 | tiznit
# Processing Record 42 of set 13 | nabire
# Processing Record 43 of set 13 | saurimo
# Processing Record 44 of set 13 | chake chake
# Processing Record 45 of set 13 | tornio
# Processing Record 46 of set 13 | strezhevoy
# Processing Record 47 of set 13 | berlevag
# Processing Record 48 of set 13 | jinsha
# Processing Record 49 of set 13 | palekh
# Processing Record 50 of set 13 | cairns
# Processing Record 1 of set 14 | alta floresta
# Processing Record 2 of set 14 | jaciara
# Processing Record 3 of set 14 | maues
# Processing Record 4 of set 14 | natal
# Processing Record 5 of set 14 | sumbawa
# City not found. Skipping...
# Processing Record 6 of set 14 | grants
# Processing Record 7 of set 14 | payo
# Processing Record 8 of set 14 | samagaltay
# Processing Record 9 of set 14 | flinders
# Processing Record 10 of set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 11 of set 14 | santa isabel do rio negro
# Processing Record 12 of set 14 | hasilpur
# Processing Record 13 of set 14 | ushtobe
# Processing Record 14 of set 14 | hampton
# Processing Record 15 of set 14 | tocopilla
# Processing Record 16 of set 14 | san quintin
# Processing Record 17 of set 14 | chateau-thierry
# Processing Record 18 of set 14 | krasnyy chikoy
# Processing Record 19 of set 14 | seddon
# Processing Record 20 of set 14 | inndyr
# Processing Record 21 of set 14 | jalu
# Processing Record 22 of set 14 | piranshahr
# Processing Record 23 of set 14 | paracuru
# Processing Record 24 of set 14 | bumbuna
# Processing Record 25 of set 14 | luwuk
# Processing Record 26 of set 14 | marshall
# Processing Record 27 of set 14 | xining
# Processing Record 28 of set 14 | markova
# Processing Record 29 of set 14 | chiknayakanhalli
# Processing Record 30 of set 14 | mae sai
# Processing Record 31 of set 14 | sena madureira
# Processing Record 32 of set 14 | skjervoy
# Processing Record 33 of set 14 | weimar
# Processing Record 34 of set 14 | raga
# Processing Record 35 of set 14 | mill valley
# Processing Record 36 of set 14 | port shepstone
# Processing Record 37 of set 14 | poum
# Processing Record 38 of set 14 | chiang rai
# Processing Record 39 of set 14 | taua
# Processing Record 40 of set 14 | seoul
# Processing Record 41 of set 14 | sault sainte marie
# Processing Record 42 of set 14 | kensington
# Processing Record 43 of set 14 | zuidhorn
# Processing Record 44 of set 14 | bud
# Processing Record 45 of set 14 | cooma
# Processing Record 46 of set 14 | tuzamapan
# Processing Record 47 of set 14 | elko
# Processing Record 48 of set 14 | quatre cocos
# Processing Record 49 of set 14 | kulu
# Processing Record 50 of set 14 | chigorodo
# Processing Record 1 of set 15 | owen sound
# Processing Record 2 of set 15 | beidao
# Processing Record 3 of set 15 | mwanza
# Processing Record 4 of set 15 | abancay
# Processing Record 5 of set 15 | zarubino
# Processing Record 6 of set 15 | meru
# Processing Record 7 of set 15 | vostok
# Processing Record 8 of set 15 | saint-pierre
# Processing Record 9 of set 15 | marmande
# Processing Record 10 of set 15 | kangaba
# Processing Record 11 of set 15 | marsa matruh
# Processing Record 12 of set 15 | murupara
# Processing Record 13 of set 15 | maceio
# Processing Record 14 of set 15 | katha
# City not found. Skipping...
# Processing Record 15 of set 15 | banjar
# Processing Record 16 of set 15 | port hedland
# Processing Record 17 of set 15 | neuquen
# Processing Record 18 of set 15 | bouca
# Processing Record 19 of set 15 | vila velha
# Processing Record 20 of set 15 | pumiao
# Processing Record 21 of set 15 | port pirie
# Processing Record 22 of set 15 | margate
# Processing Record 23 of set 15 | mabaruma
# Processing Record 24 of set 15 | hualmay
# Processing Record 25 of set 15 | punta cardon
# Processing Record 26 of set 15 | bani
# Processing Record 27 of set 15 | yingcheng
# Processing Record 28 of set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 29 of set 15 | houma
# Processing Record 30 of set 15 | lompoc
# Processing Record 31 of set 15 | south river
# Processing Record 32 of set 15 | lalomanu
# City not found. Skipping...
# Processing Record 33 of set 15 | xichang
# Processing Record 34 of set 15 | chokwe
# Processing Record 35 of set 15 | dese
# Processing Record 36 of set 15 | iberia
# Processing Record 37 of set 15 | lufilufi
# Processing Record 38 of set 15 | westport
# Processing Record 39 of set 15 | ban nahin
# Processing Record 40 of set 15 | mergui
# City not found. Skipping...
# Processing Record 41 of set 15 | saint-raymond
# Processing Record 42 of set 15 | barcelos
# Processing Record 43 of set 15 | hami
# Processing Record 44 of set 15 | san carlos de bariloche
# Processing Record 45 of set 15 | guarapari
# Processing Record 46 of set 15 | fernley
# Processing Record 47 of set 15 | tall kayf
# Processing Record 48 of set 15 | izumo
# Processing Record 49 of set 15 | thessalon
# Processing Record 50 of set 15 | pacifica
# Processing Record 1 of set 16 | praia
# Processing Record 2 of set 16 | teguise
# Processing Record 3 of set 16 | puerto madryn
# Processing Record 4 of set 16 | ayan
# Processing Record 5 of set 16 | beringovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#converts the array of dictionaries to a pandas dataframe
city_data_df = pd.DataFrame(city_data)

#make sures column order is correct
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

city_data_df = city_data_df[new_column_order]

# %%
#creates the output CSV file
output_data_file = '../Weather_Database/WeatherPy_Database.csv'

#exports city_data_df into a csv
city_data_df.to_csv(output_data_file, index_label = 'City_ID')

# %%
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe      RE -21.3585   55.7679     80.60        61          90
# 1     Yellowknife      CA  62.4560 -114.3525    -34.01        67          40
# 2       Geraldton      AU -28.7667  114.6000     73.40        68          40
# 3       Carnarvon      AU -24.8667  113.6333     82.40       100          40
# 4     Clyde River      CA  70.4692  -68.5914     -7.60        92           1
#
#    Wind Speed Current Description
# 0        8.05     overcast clouds
# 1        8.05    scattered clouds
# 2       14.97    scattered clouds
# 3       14.97    scattered clouds
# 4        3.44                mist
